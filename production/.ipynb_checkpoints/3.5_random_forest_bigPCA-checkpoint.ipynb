# %% [markdown]
# # Perform Random Forest Analysis on acoustic measures
#
# Input large df with acoustic measures for each vowel in each word and output feature importance.

# %%
import pandas as pd
import numpy as np
from numpy import mean
from numpy import std
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.colors as mcolors
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold as kfold
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
import matplotlib.cbook as cbook

# %%
df = pd.read_csv("data/data.csv")
df.head()
# Out:
#    spectilt        f0     creak                  Filename Label  partID  \
# 0 -1.948128  2.018872  0.237973  afs116_catala_exp2_a.mat     i  afs116
# 1  3.364554  3.614688 -0.335603  afs116_catala_exp2_a.mat     a  afs116
# 2  3.467696  2.321223 -2.259574  afs116_catala_exp2_a.mat     i  afs116
# 3  3.964832  3.672432 -0.065376  afs116_catala_exp2_a.mat     a  afs116
# 4  4.339577  2.460223 -3.129166  afs116_catala_exp2_a.mat     i  afs116
#
#   Language      t1_wd    t2_wd  stress   syl_dur     v_dur  sF1_norm  \
# 0      cat   5.502012   6.2491       0  0.145897  0.071737  0.364659
# 1      cat   5.502012   6.2491       1  0.369100  0.274665  0.590216
# 2      cat  10.850600  12.0906       0  0.220000  0.114457  0.324272
# 3      cat  10.850600  12.0906       1  0.550000  0.300000  0.616292
# 4      cat  40.617489  42.1002       0  0.333645  0.198018  0.363943
#
#    sF2_norm  pF1_norm  pF2_norm
# 0  1.005592  0.600464  1.976100
# 1  1.232494  0.743332  1.122566
# 2  1.024262  0.675783  2.394210
# 3  1.276431  0.690222  1.123915
# 4  1.033499  0.671437  2.407024

# %%
scaler = StandardScaler()
df['v_dur'] = scaler.fit_transform(df['v_dur'].values.reshape(-1,1))
df['syl_dur'] = scaler.fit_transform(df['syl_dur'].values.reshape(-1,1))
df['sF1_norm_center'] = df['sF1_norm']-0.5
df['pF1_norm_center'] = df['pF1_norm']-0.5
df['sF2_norm_center'] = df['sF2_norm']-1.5
df['pF2_norm_center'] = df['pF2_norm']-1.5
df['s_deltaF_dist'] = np.sqrt(np.square(df['sF1_norm_center']) + 
                                           np.square(df['sF2_norm_center']))
df['p_deltaF_dist'] = np.sqrt(np.square(df['pF1_norm_center']) + 
                                           np.square(df['pF2_norm_center']))
df['s_deltaF_dist'] = scaler.fit_transform(df['s_deltaF_dist'].values.reshape(-1,1))
df['p_deltaF_dist'] = scaler.fit_transform(df['p_deltaF_dist'].values.reshape(-1,1))

# %%
df.head()
# Out:
#    spectilt        f0     creak                  Filename Label  partID  \
# 0 -1.948128  2.018872  0.237973  afs116_catala_exp2_a.mat     i  afs116
# 1  3.364554  3.614688 -0.335603  afs116_catala_exp2_a.mat     a  afs116
# 2  3.467696  2.321223 -2.259574  afs116_catala_exp2_a.mat     i  afs116
# 3  3.964832  3.672432 -0.065376  afs116_catala_exp2_a.mat     a  afs116
# 4  4.339577  2.460223 -3.129166  afs116_catala_exp2_a.mat     i  afs116
#
#   Language      t1_wd    t2_wd  stress  ...  sF1_norm  sF2_norm  pF1_norm  \
# 0      cat   5.502012   6.2491       0  ...  0.364659  1.005592  0.600464
# 1      cat   5.502012   6.2491       1  ...  0.590216  1.232494  0.743332
# 2      cat  10.850600  12.0906       0  ...  0.324272  1.024262  0.675783
# 3      cat  10.850600  12.0906       1  ...  0.616292  1.276431  0.690222
# 4      cat  40.617489  42.1002       0  ...  0.363943  1.033499  0.671437
#
#    pF2_norm  sF1_norm_center  pF1_norm_center  sF2_norm_center  \
# 0  1.976100        -0.135341         0.100464        -0.494408
# 1  1.122566         0.090216         0.243332        -0.267506
# 2  2.394210        -0.175728         0.175783        -0.475738
# 3  1.123915         0.116292         0.190222        -0.223569
# 4  2.407024        -0.136057         0.171437        -0.466501
#
#    pF2_norm_center  s_deltaF_dist  p_deltaF_dist
# 0         0.476100       0.454568       0.839891
# 1        -0.377434      -0.465628       0.652753
# 2         0.894210       0.432822       2.958907
# 3        -0.376085      -0.586717       0.514964
# 4         0.907024       0.348036       3.017575
#
# [5 rows x 22 columns]

# %%
df.columns
# Out:
# Index(['spectilt', 'f0', 'creak', 'Filename', 'Label', 'partID', 'Language',
#        't1_wd', 't2_wd', 'stress', 'syl_dur', 'v_dur', 'sF1_norm', 'sF2_norm',
#        'pF1_norm', 'pF2_norm', 'sF1_norm_center', 'pF1_norm_center',
#        'sF2_norm_center', 'pF2_norm_center', 's_deltaF_dist', 'p_deltaF_dist'],
#       dtype='object')

# %%
df.drop(['sF1_norm', 'sF2_norm', 'pF1_norm', 'pF2_norm', 'sF1_norm_center', 'pF1_norm_center',
        'sF2_norm_center', 'pF2_norm_center'], axis = 1, inplace = True)

# %%
df_1 = df[(df['Label']=="i") | (df['Label']=="pen")].copy()
df_2 = df[(df['Label']!="i") & (df['Label']!="pen")].copy()

# %%
df_wd = pd.merge(df_1, df_2, on=['Filename', 't1_wd', 't2_wd', 'partID', 'Language'],
                 suffixes=('_vowel1', '_vowel2'))

# %% [markdown]
# Label row as `Paroxytone` if vowel 1 is stressed and `Oxytone` if vowel 2 is stressed.

# %%
df_wd['stress_wd'] = np.where(df_wd['stress_vowel1']==1, 'Paroxytone', 'Oxytone')

# %% [markdown]
# New column for vowel duration ratio, new column for syllable duration ratio, new column for Delta F distance from center calculation, new column for energy ratio.

# %%
df_wd['vdur_ratio'] = df_wd['v_dur_vowel1'] / df_wd['v_dur_vowel2']
df_wd['syldur_ratio'] = df_wd['syl_dur_vowel1'] / df_wd['syl_dur_vowel2']
df_wd['s_deltaF_dist_ratio'] = df_wd['s_deltaF_dist_vowel1']/df_wd['s_deltaF_dist_vowel2']
df_wd['p_deltaF_dist_ratio'] = df_wd['p_deltaF_dist_vowel1']/df_wd['p_deltaF_dist_vowel2']
df_wd['f0_ratio'] = df_wd['f0_vowel1']/df_wd['f0_vowel2']
df_wd['spectilt_ratio'] = df_wd['spectilt_vowel1']/df_wd['spectilt_vowel2']
df_wd['creak_ratio'] = df_wd['creak_vowel1']/df_wd['creak_vowel2']

# %%
df_wd.columns
# Out:
# Index(['spectilt_vowel1', 'f0_vowel1', 'creak_vowel1', 'Filename',
#        'Label_vowel1', 'partID', 'Language', 't1_wd', 't2_wd', 'stress_vowel1',
#        'syl_dur_vowel1', 'v_dur_vowel1', 's_deltaF_dist_vowel1',
#        'p_deltaF_dist_vowel1', 'spectilt_vowel2', 'f0_vowel2', 'creak_vowel2',
#        'Label_vowel2', 'stress_vowel2', 'syl_dur_vowel2', 'v_dur_vowel2',
#        's_deltaF_dist_vowel2', 'p_deltaF_dist_vowel2', 'stress_wd',
#        'vdur_ratio', 'syldur_ratio', 's_deltaF_dist_ratio',
#        'p_deltaF_dist_ratio', 'f0_ratio', 'spectilt_ratio', 'creak_ratio'],
#       dtype='object')

# %%
df_wd.drop(['Filename', 't1_wd', 't2_wd', 'Label_vowel1', 'Label_vowel2', 'stress_vowel1', 'stress_vowel2'], axis = 1,
          inplace = True)
df_wd.columns
# Out:
# Index(['spectilt_vowel1', 'f0_vowel1', 'creak_vowel1', 'partID', 'Language',
#        'syl_dur_vowel1', 'v_dur_vowel1', 's_deltaF_dist_vowel1',
#        'p_deltaF_dist_vowel1', 'spectilt_vowel2', 'f0_vowel2', 'creak_vowel2',
#        'syl_dur_vowel2', 'v_dur_vowel2', 's_deltaF_dist_vowel2',
#        'p_deltaF_dist_vowel2', 'stress_wd', 'vdur_ratio', 'syldur_ratio',
#        's_deltaF_dist_ratio', 'p_deltaF_dist_ratio', 'f0_ratio',
#        'spectilt_ratio', 'creak_ratio'],
#       dtype='object')

# %%
subset = df_wd.drop(['vdur_ratio', 'syldur_ratio', 's_deltaF_dist_ratio', 'p_deltaF_dist_ratio', 'f0_ratio',
                    'spectilt_ratio', 'creak_ratio'], axis = 1)

# %%
cor= subset.corr(method='pearson')
fig, ax =plt.subplots(figsize=(8, 6))
plt.title("Correlation Plot")
sns.heatmap(cor, mask=np.zeros_like(cor, dtype=np.bool), cmap=sns.diverging_palette(220, 10, as_cmap=True),
            square=True, ax=ax)
plt.show()

# %% [markdown]
# Columns to drop: `Filename`, `stress_vowel1`, `stress_vowel2`, `v_dur_vowel1`, `v_dur_vowel2`, `sF1_norm_vowel1`, `sF1_norm_vowel2`, `sF2_norm_vowel1`, `sF2_norm_vowel2`, `pF1_norm_vowel1`, `pF2_norm_vowel1`, `pF1_norm_vowel2`, `pF2_norm_vowel2`

# %%
df_wd.drop(['Filename', 'stress_vowel1', 'stress_vowel2', 'Label_vowel1', 'Label_vowel2',
           't1_wd', 't2_wd',
            'v_dur_vowel1','v_dur_vowel2', 'syl_dur_vowel1', 'syl_dur_vowel2',
            'f0_vowel1', 'f0_vowel2', 'spectilt_vowel1', 'spectilt_vowel2', 's_deltaF_dist_vowel1',
            's_deltaF_dist_vowel2', 'p_deltaF_dist_vowel1', 'p_deltaF_dist_vowel2',
            'creak_vowel1','creak_vowel2'],
           axis = 1, inplace = True)
df_wd.sample(5)
# Out:
#        partID Language   stress_wd  vdur_ratio  syldur_ratio  \
# 9801   srm056      eng     Oxytone   -0.156161     -0.239664
# 13111  nie059      spa     Oxytone -153.758306      1.530990
# 1105   acr108      eng     Oxytone    1.000000      1.895474
# 4731   asl181      eng     Oxytone   -2.838663     -1.052561
# 1252   acr108      spa  Paroxytone   -6.399733      3.646229
#
#        s_deltaF_dist_ratio  p_deltaF_dist_ratio  f0_ratio  spectilt_ratio  \
# 9801             -0.160745            -0.765565  5.655740       -0.451203
# 13111             1.071624             1.012264  0.355288       -0.602986
# 1105             -2.444916            -0.045295  0.919937        1.009448
# 4731              2.662790             0.415777  0.727193       -1.054547
# 1252              0.508196            -0.210020  0.892817       -0.778983
#
#        creak_ratio
# 9801     -0.637174
# 13111     0.066595
# 1105      0.655865
# 4731     -0.147963
# 1252     -0.622091

# %%
cor= df_wd.corr(method='pearson')
print(cor)
# Out:
#                      vdur_ratio  syldur_ratio  s_deltaF_dist_ratio  \
# vdur_ratio             1.000000      0.000646             0.000265
# syldur_ratio           0.000646      1.000000            -0.002783
# s_deltaF_dist_ratio    0.000265     -0.002783             1.000000
# p_deltaF_dist_ratio    0.000136      0.007930             0.000517
# f0_ratio               0.000049      0.000487             0.017827
# spectilt_ratio        -0.002997     -0.000782            -0.000250
# creak_ratio            0.001158      0.000485            -0.002850
#
#                      p_deltaF_dist_ratio  f0_ratio  spectilt_ratio  \
# vdur_ratio                      0.000136  0.000049       -0.002997
# syldur_ratio                    0.007930  0.000487       -0.000782
# s_deltaF_dist_ratio             0.000517  0.017827       -0.000250
# p_deltaF_dist_ratio             1.000000 -0.000359       -0.000378
# f0_ratio                       -0.000359  1.000000        0.000078
# spectilt_ratio                 -0.000378  0.000078        1.000000
# creak_ratio                    -0.000661  0.010184        0.000199
#
#                      creak_ratio
# vdur_ratio              0.001158
# syldur_ratio            0.000485
# s_deltaF_dist_ratio    -0.002850
# p_deltaF_dist_ratio    -0.000661
# f0_ratio                0.010184
# spectilt_ratio          0.000199
# creak_ratio             1.000000

# %%
fig, ax =plt.subplots(figsize=(8, 6))
plt.title("Correlation Plot")
sns.heatmap(cor, mask=np.zeros_like(cor, dtype=np.bool), cmap=sns.diverging_palette(220, 10, as_cmap=True),
            square=True, ax=ax)
plt.show()

# %% [markdown]
# Look for empty rows

# %%
df_wd.isnull().sum()
# Out:
# partID                 0
# Language               0
# stress_wd              0
# vdur_ratio             0
# syldur_ratio           0
# s_deltaF_dist_ratio    0
# p_deltaF_dist_ratio    0
# f0_ratio               0
# spectilt_ratio         0
# creak_ratio            0
# dtype: int64

# %%
y_all = df_wd['stress_wd']
X_all = df_wd.drop(['stress_wd', 'Language', 'partID'], axis = 1)
    
rf_classifier = RandomForestClassifier(random_state = 10)
    
param_grid = { 
    'n_estimators': [500],
    'max_features': ['auto', 'sqrt', 'log2'],
    'max_depth' : np.arange(4,10,1),
    'criterion' :['gini', 'entropy']
}

CV_rfc = GridSearchCV(estimator=rf_classifier, param_grid=param_grid, cv= 5)
CV_rfc.fit(X_all, y_all)
    
print("Best RF Estimator: ", CV_rfc.best_params_, "\n")
    
scores = cross_val_score(rf_classifier, X_all, y_all.ravel(), cv=5)
print("Accuracy over all data: ", scores.mean())
    
rf_classifier_best = CV_rfc.best_estimator_

cols = X_all.columns
# Out:
# Best RF Estimator:  {'criterion': 'gini', 'max_depth': 9, 'max_features': 'auto', 'n_estimators': 500}
#
# Accuracy over all data:  0.6808959768239381

# %%
def rf(df, rf_classifier_best, cols):
    lang = []
    partid = []
    dfs = []
        
    for p in df.partID.unique():
        data = df[df['partID']==p].copy()
        
        for l in data.Language.unique():
            # isolate language of interest
            data1 = data[data['Language']==l].copy()
            data1.drop(['Language', 'partID'], axis = 1, inplace = True)
            data1.reset_index(inplace = True, drop = True)
            
            # define predictor label
            y = data1['stress_wd']

            # define feature set
            X = data1.drop(['stress_wd'], axis = 1)
            
            rf_classifier_best.fit(X, y.ravel())
            importances = rf_classifier_best.feature_importances_
            std = np.std([tree.feature_importances_ for tree in rf_classifier_best.estimators_], axis=0)
            q_25 = np.percentile([tree.feature_importances_ for tree in rf_classifier_best.estimators_], 25, axis = 0)
            q_75 = np.percentile([tree.feature_importances_ for tree in rf_classifier_best.estimators_], 75, axis = 0)
            
            # make df
            columns = ['Feature', 'Importance (MDI)', 'Std', 'q25', 'q75']
            rfs = pd.DataFrame([cols, importances, std, q_25, q_75]).transpose()
            rfs.columns = columns
            rfs['Language'] = l
            rfs['partID'] = p
            dfs.append(rfs)
        
    rf_df = pd.concat(dfs)
        
    return(rf_df)

# %%
rf_df = rf(df_wd, rf_classifier_best, cols)
rf_df.head()
# Out:
#                Feature Importance (MDI)       Std  q25       q75 Language  \
# 0           vdur_ratio         0.150264  0.235987  0.0  0.232287      cat
# 1         syldur_ratio         0.183648  0.267787  0.0  0.324908      cat
# 2  s_deltaF_dist_ratio         0.057348  0.142135  0.0       0.0      cat
# 3  p_deltaF_dist_ratio         0.112162   0.21161  0.0  0.145706      cat
# 4             f0_ratio         0.097282  0.211352  0.0  0.088877      cat
#
#    partID
# 0  afs116
# 1  afs116
# 2  afs116
# 3  afs116
# 4  afs116

# %%
rf_df['partID'].mask(rf_df['partID'] == 'rsj048', 'rsj0489', inplace=True)

# %% [markdown]
# Merge in BLP PCA components.

# %%
parts = pd.read_csv("../blp/data/parts.csv")
parts['partID'] = parts['partID'].map(str.lower)

# %%
rf_lang = pd.merge(rf_df, parts, on = "partID", how = "left")
rf_lang.head()
# Out:
#                Feature Importance (MDI)       Std  q25       q75 Language  \
# 0           vdur_ratio         0.150264  0.235987  0.0  0.232287      cat
# 1         syldur_ratio         0.183648  0.267787  0.0  0.324908      cat
# 2  s_deltaF_dist_ratio         0.057348  0.142135  0.0       0.0      cat
# 3  p_deltaF_dist_ratio         0.112162   0.21161  0.0  0.145706      cat
# 4             f0_ratio         0.097282  0.211352  0.0  0.088877      cat
#
#    partID lang_profile
# 0  afs116       l1_eng
# 1  afs116       l1_eng
# 2  afs116       l1_eng
# 3  afs116       l1_eng
# 4  afs116       l1_eng

# %%
blp_pca = pd.read_csv("../blp/data/pca_blp.csv")
blp_pca.drop(['lang_profile'], axis = 1, inplace = True)

# %%
rf_df_blp = pd.merge(rf_lang, blp_pca, on="partID", how = "left")
rf_df_blp.sample(10)
# Out:
#                   Feature Importance (MDI)       Std       q25       q75  \
# 894        spectilt_ratio         0.107543  0.080891    0.0477  0.153529
# 214              f0_ratio         0.140686  0.110492   0.04815   0.21088
# 1114         syldur_ratio         0.179174  0.114823  0.090242  0.257792
# 1011  p_deltaF_dist_ratio         0.038696   0.06097       0.0  0.061184
# 250        spectilt_ratio         0.144916  0.115475  0.050604  0.220176
# 223           creak_ratio         0.089015  0.101846       0.0  0.140224
# 1012             f0_ratio         0.188711  0.182461  0.036905  0.335113
# 345   s_deltaF_dist_ratio         0.100343  0.089207  0.026338  0.156171
# 129   p_deltaF_dist_ratio         0.144101  0.146418       0.0  0.245653
# 960          syldur_ratio          0.12559   0.12141  0.018859    0.1907
#
#      Language  partID lang_profile       pc1       pc2
# 894       eng  anm149       l1_eng  1.556867  0.403033
# 214       spa  alc125       l3_eng -4.133254  1.463685
# 1114      eng  odm115         mono       NaN       NaN
# 1011      cat  hya248       l1_eng  3.141377 -0.189414
# 250       eng  als086       l3_eng -3.718344 -3.322950
# 223       cat  als024       l1_eng  3.276001 -1.693311
# 1012      cat  hya248       l1_eng  3.141377 -0.189414
# 345       spa  arc053       l3_eng -4.384488 -0.104776
# 129       spa  aei079       l1_eng  4.173198  2.576465
# 960       spa  eir057       l1_eng  4.932414 -1.595612

# %%
rf_df_blp['Stdx2'] = rf_df_blp['Std']*2

# %%
rf_df_blp.to_csv("data/rf_by_parts.csv", index = False)

# %% [markdown]
# ## Visualize across BLP components

# %%
df = pd.read_csv("data/rf_by_parts.csv")
df.head()
# Out:
#                Feature  Importance (MDI)       Std  q25       q75 Language  \
# 0           vdur_ratio          0.150264  0.235987  0.0  0.232287      cat
# 1         syldur_ratio          0.183648  0.267787  0.0  0.324908      cat
# 2  s_deltaF_dist_ratio          0.057348  0.142135  0.0  0.000000      cat
# 3  p_deltaF_dist_ratio          0.112162  0.211610  0.0  0.145706      cat
# 4             f0_ratio          0.097282  0.211352  0.0  0.088877      cat
#
#    partID lang_profile       pc1       pc2     Stdx2
# 0  afs116       l1_eng  6.165044  2.991184  0.471974
# 1  afs116       l1_eng  6.165044  2.991184  0.535575
# 2  afs116       l1_eng  6.165044  2.991184  0.284270
# 3  afs116       l1_eng  6.165044  2.991184  0.423220
# 4  afs116       l1_eng  6.165044  2.991184  0.422704

# %%
eng = df[(df['Language']=="eng") & (df['lang_profile']!='mono')].copy()
eng.sample(10)
# Out:
#                   Feature  Importance (MDI)       Std       q25       q75  \
# 719        spectilt_ratio          0.136231  0.101046  0.059203  0.192397
# 955   p_deltaF_dist_ratio          0.106552  0.080981  0.045781  0.152993
# 102              f0_ratio          0.111862  0.084442  0.046156  0.160000
# 590   s_deltaF_dist_ratio          0.120607  0.095746  0.045193  0.175440
# 478   s_deltaF_dist_ratio          0.111750  0.085877  0.041376  0.166467
# 931            vdur_ratio          0.286705  0.161649  0.155836  0.399353
# 1137  p_deltaF_dist_ratio          0.114736  0.077970  0.059295  0.164464
# 1104       spectilt_ratio          0.201910  0.199052  0.046996  0.349374
# 269   p_deltaF_dist_ratio          0.098842  0.077985  0.037519  0.144819
# 912   s_deltaF_dist_ratio          0.093990  0.081284  0.031750  0.147048
#
#      Language  partID lang_profile       pc1       pc2     Stdx2
# 719       eng  nir048       l1_eng  3.892734 -2.726815  0.202091
# 955       eng  eir057       l1_eng  4.932414 -1.595612  0.161963
# 102       eng  acr108       l1_eng  3.094974 -0.507547  0.168883
# 590       eng  ldm015       l3_eng -6.873663  2.552005  0.191491
# 478       eng  enp048       l3_eng -3.268563 -3.386351  0.171755
# 931       eng  dis022       l1_eng  5.450197 -0.136048  0.323297
# 1137      eng  orx026       l1_eng  5.320339 -0.596798  0.155940
# 1104      eng  nie059       l1_eng  4.275527  0.513053  0.398104
# 269       eng  ama302       l1_eng  5.471769 -1.074763  0.155970
# 912       eng  arr030       l3_eng -4.591304 -3.365294  0.162569

# %%
v_dur = eng[eng['Feature']=="vdur_ratio"].copy()
syl_dur = eng[eng['Feature']=="syldur_ratio"].copy()
f0 = eng[eng['Feature']=="f0_ratio"].copy()
creak = eng[eng['Feature']=="creak_ratio"].copy()
sdelta = eng[eng['Feature']=="s_deltaF_dist_ratio"].copy()
pdelta = eng[eng['Feature']=="p_deltaF_dist_ratio"].copy()
spectilt = eng[eng['Feature']=="spectilt_ratio"].copy()
v_dur.head()
# Out:
#        Feature  Importance (MDI)       Std       q25       q75 Language  \
# 7   vdur_ratio          0.161000  0.112417  0.078096  0.220968      eng
# 28  vdur_ratio          0.164005  0.107699  0.083947  0.232809      eng
# 49  vdur_ratio          0.209561  0.149629  0.088684  0.299136      eng
# 77  vdur_ratio          0.247874  0.151743  0.130647  0.344887      eng
# 98  vdur_ratio          0.222574  0.125991  0.115544  0.303651      eng
#
#     partID lang_profile       pc1       pc2     Stdx2
# 7   afs116       l1_eng  6.165044  2.991184  0.224833
# 28  ala059       l3_eng -2.514206 -3.853363  0.215398
# 49  irb111       l3_eng -4.302327 -0.077543  0.299259
# 77  acj297       l1_eng  3.764211 -1.240101  0.303486
# 98  acr108       l1_eng  3.094974 -0.507547  0.251982

# %%
tex_fonts = {
    "font.family": "serif",
    # Use 10pt font in plots, to match 10pt font in document
    "axes.labelsize": 12,
    "font.size": 10,
    # Make the legend/label fonts a little smaller
    "legend.fontsize": 10,
    "xtick.labelsize": 10,
    "ytick.labelsize": 10
}
plt.rcParams.update(tex_fonts)

fig, axes = plt.subplots(2,4,
                         sharey = True, sharex = True, figsize = (15,6))
plt.subplots_adjust(hspace = 0.3)
sns.scatterplot(ax = axes[0,0], x = v_dur.pc1,
                y = v_dur['Importance (MDI)'], alpha = 0.7, color = "blue")

axes[0,0].errorbar(v_dur.pc1, v_dur['Importance (MDI)'],
                 yerr=v_dur.Stdx2,
                 fmt=' ', zorder=-1, alpha = 0.3, color = "black")
axes[0,0].axhline(y = 0, color = "black", linestyle = "--", alpha = 0.5)
axes[0,0].set_title("Vowel duration")

axes[0,1].axhline(y = 0, color = "black", linestyle = "--", alpha = 0.5)
axes[0,1].set_title("Syllable duration")
axes[0,2].axhline(y = 0, color = "black", linestyle = "--", alpha = 0.5)
axes[0,2].set_title("Vowel peripherity (Snack)")
sns.scatterplot(ax = axes[0,1], x = syl_dur.pc1,
                y = syl_dur['Importance (MDI)'], alpha = 0.7, color = "green")
axes[0,1].errorbar(syl_dur.pc1, syl_dur['Importance (MDI)'],
                 yerr=syl_dur.Stdx2,
                 fmt=' ', zorder=-1, alpha = 0.3, color = "black")

sns.scatterplot(ax = axes[0,2], x = sdelta.pc1,
                y = sdelta['Importance (MDI)'], alpha = 0.7, color = "red")
axes[0,2].errorbar(sdelta.pc1, sdelta['Importance (MDI)'],
                 yerr=sdelta.Stdx2,
                 fmt=' ', zorder=-1, alpha = 0.3, color = "black")

axes[0,3].set_title("Vowel peripherity (Praat)")

sns.scatterplot(ax = axes[0,3], x = pdelta.pc1,
                y = pdelta['Importance (MDI)'], alpha = 0.7)
axes[0,3].errorbar(pdelta.pc1, pdelta['Importance (MDI)'],
                 yerr=pdelta.Stdx2,
                 fmt=' ', zorder=-1, alpha = 0.3, color = "black") 

axes[0,3].axhline(y = 0, color = "black", linestyle = "--", alpha = 0.5)

axes[1,0].set_title("F0")

sns.scatterplot(ax = axes[1,0], x = f0.pc1,
                y = f0['Importance (MDI)'], alpha = 0.7, color = "purple")
axes[1,0].errorbar(f0.pc1, f0['Importance (MDI)'],
                 yerr=f0.Stdx2,
                 fmt=' ', zorder=-1, alpha = 0.3, color = "black")
axes[1,0].axhline(y = 0, color = "black", linestyle = "--", alpha = 0.5)

axes[1,1].set_title("Spectral tilt")

sns.scatterplot(ax = axes[1,1], x = spectilt.pc1,
                y = spectilt['Importance (MDI)'], alpha = 0.7, color = "orange")
axes[1,1].errorbar(spectilt.pc1, spectilt['Importance (MDI)'],
                 yerr=spectilt.Stdx2,
                 fmt=' ', zorder=-1, alpha = 0.3, color = "black") 
axes[1,1].axhline(y = 0, color = "black", linestyle = "--", alpha = 0.5)

axes[1,2].set_title("Creak")

sns.scatterplot(ax = axes[1,2], x = creak.pc1,
                y = creak['Importance (MDI)'], alpha = 0.7, color = "brown")
axes[1,2].errorbar(creak.pc1, creak['Importance (MDI)'],
                 yerr=creak.Stdx2,
                 fmt=' ', zorder=-1, alpha = 0.3, color = "black")
axes[1,2].axhline(y = 0, color = "black", linestyle = "--", alpha = 0.5)


# axes[0,0].set_xticklabels(['', '', ''])
axes[0,0].set_xlabel("")
axes[0,1].set_xlabel("")
axes[0,2].set_xlabel("")
axes[0,3].set_xlabel("")
axes[1,0].set_xlabel("")
axes[1,1].set_xlabel("")
axes[1,2].set_xlabel("")

axes[0,0].set_ylabel("")
axes[0,1].set_ylabel("")
axes[0,2].set_ylabel("")
axes[0,3].set_ylabel("")
axes[1,0].set_ylabel("")
axes[1,1].set_ylabel("")
axes[1,2].set_ylabel("")
fig.supxlabel("First principal component (English affinity)")
fig.supylabel("Importance (MDI)")
fig.suptitle("Cue-weighting to predict English lexical stress production")
axes[1,3].remove()


# plt.ylim([-1.5,4.5])
plt.savefig('figures/eng_importance_pc1.jpg', format='jpg', dpi = 800)
plt.show();

# %%
tex_fonts = {
    "font.family": "serif",
    # Use 10pt font in plots, to match 10pt font in document
    "axes.labelsize": 12,
    "font.size": 10,
    # Make the legend/label fonts a little smaller
    "legend.fontsize": 10,
    "xtick.labelsize": 10,
    "ytick.labelsize": 10
}
plt.rcParams.update(tex_fonts)

fig, axes = plt.subplots(2,4,
                         sharey = True, sharex = True, figsize = (15,6))
plt.subplots_adjust(hspace = 0.3)
sns.scatterplot(ax = axes[0,0], x = v_dur.pc2,
                y = v_dur['Importance (MDI)'], alpha = 0.7, color = "blue")

axes[0,0].errorbar(v_dur.pc2, v_dur['Importance (MDI)'],
                 yerr=v_dur.Stdx2,
                 fmt=' ', zorder=-1, alpha = 0.3, color = "black")
axes[0,0].axhline(y = 0, color = "black", linestyle = "--", alpha = 0.5)
axes[0,0].set_title("Vowel duration")

axes[0,1].axhline(y = 0, color = "black", linestyle = "--", alpha = 0.5)
axes[0,1].set_title("Syllable duration")
axes[0,2].axhline(y = 0, color = "black", linestyle = "--", alpha = 0.5)
axes[0,2].set_title("Vowel peripherity (Snack)")
sns.scatterplot(ax = axes[0,1], x = syl_dur.pc2,
                y = syl_dur['Importance (MDI)'], alpha = 0.7, color = "green")
axes[0,1].errorbar(syl_dur.pc2, syl_dur['Importance (MDI)'],
                 yerr=syl_dur.Stdx2,
                 fmt=' ', zorder=-1, alpha = 0.3, color = "black")

sns.scatterplot(ax = axes[0,2], x = sdelta.pc2,
                y = sdelta['Importance (MDI)'], alpha = 0.7, color = "red")
axes[0,2].errorbar(sdelta.pc2, sdelta['Importance (MDI)'],
                 yerr=sdelta.Stdx2,
                 fmt=' ', zorder=-1, alpha = 0.3, color = "black")

axes[0,3].set_title("Vowel peripherity (Praat)")

sns.scatterplot(ax = axes[0,3], x = pdelta.pc2,
                y = pdelta['Importance (MDI)'], alpha = 0.7)
axes[0,3].errorbar(pdelta.pc2, pdelta['Importance (MDI)'],
                 yerr=pdelta.Stdx2,
                 fmt=' ', zorder=-1, alpha = 0.3, color = "black") 

axes[0,3].axhline(y = 0, color = "black", linestyle = "--", alpha = 0.5)

axes[1,0].set_title("F0")

sns.scatterplot(ax = axes[1,0], x = f0.pc2,
                y = f0['Importance (MDI)'], alpha = 0.7, color = "purple")
axes[1,0].errorbar(f0.pc2, f0['Importance (MDI)'],
                 yerr=f0.Stdx2,
                 fmt=' ', zorder=-1, alpha = 0.3, color = "black")
axes[1,0].axhline(y = 0, color = "black", linestyle = "--", alpha = 0.5)

axes[1,1].set_title("Spectral tilt")

sns.scatterplot(ax = axes[1,1], x = spectilt.pc2,
                y = spectilt['Importance (MDI)'], alpha = 0.7, color = "orange")
axes[1,1].errorbar(spectilt.pc2, spectilt['Importance (MDI)'],
                 yerr=spectilt.Stdx2,
                 fmt=' ', zorder=-1, alpha = 0.3, color = "black") 
axes[1,1].axhline(y = 0, color = "black", linestyle = "--", alpha = 0.5)

axes[1,2].set_title("Creak")

sns.scatterplot(ax = axes[1,2], x = creak.pc2,
                y = creak['Importance (MDI)'], alpha = 0.7, color = "brown")
axes[1,2].errorbar(creak.pc2, creak['Importance (MDI)'],
                 yerr=creak.Stdx2,
                 fmt=' ', zorder=-1, alpha = 0.3, color = "black")
axes[1,2].axhline(y = 0, color = "black", linestyle = "--", alpha = 0.5)


# axes[0,0].set_xticklabels(['', '', ''])
axes[0,0].set_xlabel("")
axes[0,1].set_xlabel("")
axes[0,2].set_xlabel("")
axes[0,3].set_xlabel("")
axes[1,0].set_xlabel("")
axes[1,1].set_xlabel("")
axes[1,2].set_xlabel("")

axes[0,0].set_ylabel("")
axes[0,1].set_ylabel("")
axes[0,2].set_ylabel("")
axes[0,3].set_ylabel("")
axes[1,0].set_ylabel("")
axes[1,1].set_ylabel("")
axes[1,2].set_ylabel("")
fig.supxlabel("Second principal component (Catalan affinity)")
fig.supylabel("Importance (MDI)")
fig.suptitle("Cue-weighting to predict English lexical stress production")
axes[1,3].remove()


# plt.ylim([-1.5,4.5])
plt.savefig('figures/eng_importance_pc2.jpg', format='jpg', dpi = 800)
plt.show();

# %%
spa = df[df['Language']=="spa"].copy()
v_dur = spa[spa['Feature']=="vdur_ratio"].copy()
syl_dur = spa[spa['Feature']=="syldur_ratio"].copy()
f0 = spa[spa['Feature']=="f0_ratio"].copy()
creak = spa[spa['Feature']=="creak_ratio"].copy()
sdelta = spa[spa['Feature']=="s_deltaF_dist_ratio"].copy()
pdelta = spa[spa['Feature']=="p_deltaF_dist_ratio"].copy()
spectilt = spa[spa['Feature']=="spectilt_ratio"].copy()

# %%
tex_fonts = {
    "font.family": "serif",
    # Use 10pt font in plots, to match 10pt font in document
    "axes.labelsize": 12,
    "font.size": 10,
    # Make the legend/label fonts a little smaller
    "legend.fontsize": 10,
    "xtick.labelsize": 10,
    "ytick.labelsize": 10
}
plt.rcParams.update(tex_fonts)

fig, axes = plt.subplots(2,4,
                         sharey = True, sharex = True, figsize = (15,6))
plt.subplots_adjust(hspace = 0.3)
sns.scatterplot(ax = axes[0,0], x = v_dur.pc1,
                y = v_dur['Importance (MDI)'], alpha = 0.7, color = "blue")

axes[0,0].errorbar(v_dur.pc1, v_dur['Importance (MDI)'],
                 yerr=v_dur.Stdx2,
                 fmt=' ', zorder=-1, alpha = 0.3, color = "black")
axes[0,0].axhline(y = 0, color = "black", linestyle = "--", alpha = 0.5)
axes[0,0].set_title("Vowel duration")

axes[0,1].axhline(y = 0, color = "black", linestyle = "--", alpha = 0.5)
axes[0,1].set_title("Syllable duration")
axes[0,2].axhline(y = 0, color = "black", linestyle = "--", alpha = 0.5)
axes[0,2].set_title("Vowel peripherity (Snack)")
sns.scatterplot(ax = axes[0,1], x = syl_dur.pc1,
                y = syl_dur['Importance (MDI)'], alpha = 0.7, color = "green")
axes[0,1].errorbar(syl_dur.pc1, syl_dur['Importance (MDI)'],
                 yerr=syl_dur.Stdx2,
                 fmt=' ', zorder=-1, alpha = 0.3, color = "black")

sns.scatterplot(ax = axes[0,2], x = sdelta.pc1,
                y = sdelta['Importance (MDI)'], alpha = 0.7, color = "red")
axes[0,2].errorbar(sdelta.pc1, sdelta['Importance (MDI)'],
                 yerr=sdelta.Stdx2,
                 fmt=' ', zorder=-1, alpha = 0.3, color = "black")

axes[0,3].set_title("Vowel peripherity (Praat)")

sns.scatterplot(ax = axes[0,3], x = pdelta.pc1,
                y = pdelta['Importance (MDI)'], alpha = 0.7)
axes[0,3].errorbar(pdelta.pc1, pdelta['Importance (MDI)'],
                 yerr=pdelta.Stdx2,
                 fmt=' ', zorder=-1, alpha = 0.3, color = "black") 

axes[0,3].axhline(y = 0, color = "black", linestyle = "--", alpha = 0.5)

axes[1,0].set_title("F0")

sns.scatterplot(ax = axes[1,0], x = f0.pc1,
                y = f0['Importance (MDI)'], alpha = 0.7, color = "purple")
axes[1,0].errorbar(f0.pc1, f0['Importance (MDI)'],
                 yerr=f0.Stdx2,
                 fmt=' ', zorder=-1, alpha = 0.3, color = "black")
axes[1,0].axhline(y = 0, color = "black", linestyle = "--", alpha = 0.5)

axes[1,1].set_title("Spectral tilt")

sns.scatterplot(ax = axes[1,1], x = spectilt.pc1,
                y = spectilt['Importance (MDI)'], alpha = 0.7, color = "orange")
axes[1,1].errorbar(spectilt.pc1, spectilt['Importance (MDI)'],
                 yerr=spectilt.Stdx2,
                 fmt=' ', zorder=-1, alpha = 0.3, color = "black") 
axes[1,1].axhline(y = 0, color = "black", linestyle = "--", alpha = 0.5)

axes[1,2].set_title("Creak")

sns.scatterplot(ax = axes[1,2], x = creak.pc1,
                y = creak['Importance (MDI)'], alpha = 0.7, color = "brown")
axes[1,2].errorbar(creak.pc1, creak['Importance (MDI)'],
                 yerr=creak.Stdx2,
                 fmt=' ', zorder=-1, alpha = 0.3, color = "black")
axes[1,2].axhline(y = 0, color = "black", linestyle = "--", alpha = 0.5)


# axes[0,0].set_xticklabels(['', '', ''])
axes[0,0].set_xlabel("")
axes[0,1].set_xlabel("")
axes[0,2].set_xlabel("")
axes[0,3].set_xlabel("")
axes[1,0].set_xlabel("")
axes[1,1].set_xlabel("")
axes[1,2].set_xlabel("")

axes[0,0].set_ylabel("")
axes[0,1].set_ylabel("")
axes[0,2].set_ylabel("")
axes[0,3].set_ylabel("")
axes[1,0].set_ylabel("")
axes[1,1].set_ylabel("")
axes[1,2].set_ylabel("")
fig.supxlabel("First principal component (English affinity)")
fig.supylabel("Importance (MDI)")
fig.suptitle("Cue-weighting to predict Spanish lexical stress production")
axes[1,3].remove()


# plt.ylim([-1.5,4.5])
plt.savefig('figures/spa_importance_pc1.jpg', format='jpg', dpi = 800)
plt.show();

# %%
tex_fonts = {
    "font.family": "serif",
    # Use 10pt font in plots, to match 10pt font in document
    "axes.labelsize": 12,
    "font.size": 10,
    # Make the legend/label fonts a little smaller
    "legend.fontsize": 10,
    "xtick.labelsize": 10,
    "ytick.labelsize": 10
}
plt.rcParams.update(tex_fonts)

fig, axes = plt.subplots(2,4,
                         sharey = True, sharex = True, figsize = (15,6))
plt.subplots_adjust(hspace = 0.3)
sns.scatterplot(ax = axes[0,0], x = v_dur.pc2,
                y = v_dur['Importance (MDI)'], alpha = 0.7, color = "blue")

axes[0,0].errorbar(v_dur.pc2, v_dur['Importance (MDI)'],
                 yerr=v_dur.Stdx2,
                 fmt=' ', zorder=-1, alpha = 0.3, color = "black")
axes[0,0].axhline(y = 0, color = "black", linestyle = "--", alpha = 0.5)
axes[0,0].set_title("Vowel duration")

axes[0,1].axhline(y = 0, color = "black", linestyle = "--", alpha = 0.5)
axes[0,1].set_title("Syllable duration")
axes[0,2].axhline(y = 0, color = "black", linestyle = "--", alpha = 0.5)
axes[0,2].set_title("Vowel peripherity (Snack)")
sns.scatterplot(ax = axes[0,1], x = syl_dur.pc2,
                y = syl_dur['Importance (MDI)'], alpha = 0.7, color = "green")
axes[0,1].errorbar(syl_dur.pc2, syl_dur['Importance (MDI)'],
                 yerr=syl_dur.Stdx2,
                 fmt=' ', zorder=-1, alpha = 0.3, color = "black")

sns.scatterplot(ax = axes[0,2], x = sdelta.pc2,
                y = sdelta['Importance (MDI)'], alpha = 0.7, color = "red")
axes[0,2].errorbar(sdelta.pc2, sdelta['Importance (MDI)'],
                 yerr=sdelta.Stdx2,
                 fmt=' ', zorder=-1, alpha = 0.3, color = "black")

axes[0,3].set_title("Vowel peripherity (Praat)")

sns.scatterplot(ax = axes[0,3], x = pdelta.pc2,
                y = pdelta['Importance (MDI)'], alpha = 0.7)
axes[0,3].errorbar(pdelta.pc2, pdelta['Importance (MDI)'],
                 yerr=pdelta.Stdx2,
                 fmt=' ', zorder=-1, alpha = 0.3, color = "black") 

axes[0,3].axhline(y = 0, color = "black", linestyle = "--", alpha = 0.5)

axes[1,0].set_title("F0")

sns.scatterplot(ax = axes[1,0], x = f0.pc2,
                y = f0['Importance (MDI)'], alpha = 0.7, color = "purple")
axes[1,0].errorbar(f0.pc2, f0['Importance (MDI)'],
                 yerr=f0.Stdx2,
                 fmt=' ', zorder=-1, alpha = 0.3, color = "black")
axes[1,0].axhline(y = 0, color = "black", linestyle = "--", alpha = 0.5)

axes[1,1].set_title("Spectral tilt")

sns.scatterplot(ax = axes[1,1], x = spectilt.pc2,
                y = spectilt['Importance (MDI)'], alpha = 0.7, color = "orange")
axes[1,1].errorbar(spectilt.pc2, spectilt['Importance (MDI)'],
                 yerr=spectilt.Stdx2,
                 fmt=' ', zorder=-1, alpha = 0.3, color = "black") 
axes[1,1].axhline(y = 0, color = "black", linestyle = "--", alpha = 0.5)

axes[1,2].set_title("Creak")

sns.scatterplot(ax = axes[1,2], x = creak.pc2,
                y = creak['Importance (MDI)'], alpha = 0.7, color = "brown")
axes[1,2].errorbar(creak.pc2, creak['Importance (MDI)'],
                 yerr=creak.Stdx2,
                 fmt=' ', zorder=-1, alpha = 0.3, color = "black")
axes[1,2].axhline(y = 0, color = "black", linestyle = "--", alpha = 0.5)


# axes[0,0].set_xticklabels(['', '', ''])
axes[0,0].set_xlabel("")
axes[0,1].set_xlabel("")
axes[0,2].set_xlabel("")
axes[0,3].set_xlabel("")
axes[1,0].set_xlabel("")
axes[1,1].set_xlabel("")
axes[1,2].set_xlabel("")

axes[0,0].set_ylabel("")
axes[0,1].set_ylabel("")
axes[0,2].set_ylabel("")
axes[0,3].set_ylabel("")
axes[1,0].set_ylabel("")
axes[1,1].set_ylabel("")
axes[1,2].set_ylabel("")
fig.supxlabel("Second principal component (Catalan affinity)")
fig.supylabel("Importance (MDI)")
fig.suptitle("Cue-weighting to predict Spanish lexical stress production")
axes[1,3].remove()


# plt.ylim([-1.5,4.5])
plt.savefig('figures/spa_importance_pc2.jpg', format='jpg', dpi = 800)
plt.show();

# %%
cat = df[df['Language']=="cat"].copy()
v_dur = cat[cat['Feature']=="vdur_ratio"].copy()
syl_dur = cat[cat['Feature']=="syldur_ratio"].copy()
f0 = cat[cat['Feature']=="f0_ratio"].copy()
creak = cat[cat['Feature']=="creak_ratio"].copy()
sdelta = cat[cat['Feature']=="s_deltaF_dist_ratio"].copy()
pdelta = cat[cat['Feature']=="p_deltaF_dist_ratio"].copy()
spectilt = cat[cat['Feature']=="spectilt_ratio"].copy()

# %%
tex_fonts = {
    "font.family": "serif",
    # Use 10pt font in plots, to match 10pt font in document
    "axes.labelsize": 12,
    "font.size": 10,
    # Make the legend/label fonts a little smaller
    "legend.fontsize": 10,
    "xtick.labelsize": 10,
    "ytick.labelsize": 10
}
plt.rcParams.update(tex_fonts)

fig, axes = plt.subplots(2,4,
                         sharey = True, sharex = True, figsize = (15,6))
plt.subplots_adjust(hspace = 0.3)
sns.scatterplot(ax = axes[0,0], x = v_dur.pc1,
                y = v_dur['Importance (MDI)'], alpha = 0.7, color = "blue")

axes[0,0].errorbar(v_dur.pc1, v_dur['Importance (MDI)'],
                 yerr=v_dur.Stdx2,
                 fmt=' ', zorder=-1, alpha = 0.3, color = "black")
axes[0,0].axhline(y = 0, color = "black", linestyle = "--", alpha = 0.5)
axes[0,0].set_title("Vowel duration")

axes[0,1].axhline(y = 0, color = "black", linestyle = "--", alpha = 0.5)
axes[0,1].set_title("Syllable duration")
axes[0,2].axhline(y = 0, color = "black", linestyle = "--", alpha = 0.5)
axes[0,2].set_title("Vowel peripherity (Snack)")
sns.scatterplot(ax = axes[0,1], x = syl_dur.pc1,
                y = syl_dur['Importance (MDI)'], alpha = 0.7, color = "green")
axes[0,1].errorbar(syl_dur.pc1, syl_dur['Importance (MDI)'],
                 yerr=syl_dur.Stdx2,
                 fmt=' ', zorder=-1, alpha = 0.3, color = "black")

sns.scatterplot(ax = axes[0,2], x = sdelta.pc1,
                y = sdelta['Importance (MDI)'], alpha = 0.7, color = "red")
axes[0,2].errorbar(sdelta.pc1, sdelta['Importance (MDI)'],
                 yerr=sdelta.Stdx2,
                 fmt=' ', zorder=-1, alpha = 0.3, color = "black")

axes[0,3].set_title("Vowel peripherity (Praat)")

sns.scatterplot(ax = axes[0,3], x = pdelta.pc1,
                y = pdelta['Importance (MDI)'], alpha = 0.7)
axes[0,3].errorbar(pdelta.pc1, pdelta['Importance (MDI)'],
                 yerr=pdelta.Stdx2,
                 fmt=' ', zorder=-1, alpha = 0.3, color = "black") 

axes[0,3].axhline(y = 0, color = "black", linestyle = "--", alpha = 0.5)

axes[1,0].set_title("F0")

sns.scatterplot(ax = axes[1,0], x = f0.pc1,
                y = f0['Importance (MDI)'], alpha = 0.7, color = "purple")
axes[1,0].errorbar(f0.pc1, f0['Importance (MDI)'],
                 yerr=f0.Stdx2,
                 fmt=' ', zorder=-1, alpha = 0.3, color = "black")
axes[1,0].axhline(y = 0, color = "black", linestyle = "--", alpha = 0.5)

axes[1,1].set_title("Spectral tilt")

sns.scatterplot(ax = axes[1,1], x = spectilt.pc1,
                y = spectilt['Importance (MDI)'], alpha = 0.7, color = "orange")
axes[1,1].errorbar(spectilt.pc1, spectilt['Importance (MDI)'],
                 yerr=spectilt.Stdx2,
                 fmt=' ', zorder=-1, alpha = 0.3, color = "black") 
axes[1,1].axhline(y = 0, color = "black", linestyle = "--", alpha = 0.5)

axes[1,2].set_title("Creak")

sns.scatterplot(ax = axes[1,2], x = creak.pc1,
                y = creak['Importance (MDI)'], alpha = 0.7, color = "brown")
axes[1,2].errorbar(creak.pc1, creak['Importance (MDI)'],
                 yerr=creak.Stdx2,
                 fmt=' ', zorder=-1, alpha = 0.3, color = "black")
axes[1,2].axhline(y = 0, color = "black", linestyle = "--", alpha = 0.5)


# axes[0,0].set_xticklabels(['', '', ''])
axes[0,0].set_xlabel("")
axes[0,1].set_xlabel("")
axes[0,2].set_xlabel("")
axes[0,3].set_xlabel("")
axes[1,0].set_xlabel("")
axes[1,1].set_xlabel("")
axes[1,2].set_xlabel("")

axes[0,0].set_ylabel("")
axes[0,1].set_ylabel("")
axes[0,2].set_ylabel("")
axes[0,3].set_ylabel("")
axes[1,0].set_ylabel("")
axes[1,1].set_ylabel("")
axes[1,2].set_ylabel("")
fig.supxlabel("First principal component (English affinity)")
fig.supylabel("Importance (MDI)")
fig.suptitle("Cue-weighting to predict Catalan lexical stress production")
axes[1,3].remove()


# plt.ylim([-1.5,4.5])
plt.savefig('figures/cat_importance_pc1.jpg', format='jpg', dpi = 800)
plt.show();

# %%
tex_fonts = {
    "font.family": "serif",
    # Use 10pt font in plots, to match 10pt font in document
    "axes.labelsize": 12,
    "font.size": 10,
    # Make the legend/label fonts a little smaller
    "legend.fontsize": 10,
    "xtick.labelsize": 10,
    "ytick.labelsize": 10
}
plt.rcParams.update(tex_fonts)

fig, axes = plt.subplots(2,4,
                         sharey = True, sharex = True, figsize = (15,6))
plt.subplots_adjust(hspace = 0.3)
sns.scatterplot(ax = axes[0,0], x = v_dur.pc2,
                y = v_dur['Importance (MDI)'], alpha = 0.7, color = "blue")

axes[0,0].errorbar(v_dur.pc2, v_dur['Importance (MDI)'],
                 yerr=v_dur.Stdx2,
                 fmt=' ', zorder=-1, alpha = 0.3, color = "black")
axes[0,0].axhline(y = 0, color = "black", linestyle = "--", alpha = 0.5)
axes[0,0].set_title("Vowel duration")

axes[0,1].axhline(y = 0, color = "black", linestyle = "--", alpha = 0.5)
axes[0,1].set_title("Syllable duration")
axes[0,2].axhline(y = 0, color = "black", linestyle = "--", alpha = 0.5)
axes[0,2].set_title("Vowel peripherity (Snack)")
sns.scatterplot(ax = axes[0,1], x = syl_dur.pc2,
                y = syl_dur['Importance (MDI)'], alpha = 0.7, color = "green")
axes[0,1].errorbar(syl_dur.pc2, syl_dur['Importance (MDI)'],
                 yerr=syl_dur.Stdx2,
                 fmt=' ', zorder=-1, alpha = 0.3, color = "black")

sns.scatterplot(ax = axes[0,2], x = sdelta.pc2,
                y = sdelta['Importance (MDI)'], alpha = 0.7, color = "red")
axes[0,2].errorbar(sdelta.pc2, sdelta['Importance (MDI)'],
                 yerr=sdelta.Stdx2,
                 fmt=' ', zorder=-1, alpha = 0.3, color = "black")

axes[0,3].set_title("Vowel peripherity (Praat)")

sns.scatterplot(ax = axes[0,3], x = pdelta.pc2,
                y = pdelta['Importance (MDI)'], alpha = 0.7)
axes[0,3].errorbar(pdelta.pc2, pdelta['Importance (MDI)'],
                 yerr=pdelta.Stdx2,
                 fmt=' ', zorder=-1, alpha = 0.3, color = "black") 

axes[0,3].axhline(y = 0, color = "black", linestyle = "--", alpha = 0.5)

axes[1,0].set_title("F0")

sns.scatterplot(ax = axes[1,0], x = f0.pc2,
                y = f0['Importance (MDI)'], alpha = 0.7, color = "purple")
axes[1,0].errorbar(f0.pc2, f0['Importance (MDI)'],
                 yerr=f0.Stdx2,
                 fmt=' ', zorder=-1, alpha = 0.3, color = "black")
axes[1,0].axhline(y = 0, color = "black", linestyle = "--", alpha = 0.5)

axes[1,1].set_title("Spectral tilt")

sns.scatterplot(ax = axes[1,1], x = spectilt.pc2,
                y = spectilt['Importance (MDI)'], alpha = 0.7, color = "orange")
axes[1,1].errorbar(spectilt.pc2, spectilt['Importance (MDI)'],
                 yerr=spectilt.Stdx2,
                 fmt=' ', zorder=-1, alpha = 0.3, color = "black") 
axes[1,1].axhline(y = 0, color = "black", linestyle = "--", alpha = 0.5)

axes[1,2].set_title("Creak")

sns.scatterplot(ax = axes[1,2], x = creak.pc2,
                y = creak['Importance (MDI)'], alpha = 0.7, color = "brown")
axes[1,2].errorbar(creak.pc2, creak['Importance (MDI)'],
                 yerr=creak.Stdx2,
                 fmt=' ', zorder=-1, alpha = 0.3, color = "black")
axes[1,2].axhline(y = 0, color = "black", linestyle = "--", alpha = 0.5)


# axes[0,0].set_xticklabels(['', '', ''])
axes[0,0].set_xlabel("")
axes[0,1].set_xlabel("")
axes[0,2].set_xlabel("")
axes[0,3].set_xlabel("")
axes[1,0].set_xlabel("")
axes[1,1].set_xlabel("")
axes[1,2].set_xlabel("")

axes[0,0].set_ylabel("")
axes[0,1].set_ylabel("")
axes[0,2].set_ylabel("")
axes[0,3].set_ylabel("")
axes[1,0].set_ylabel("")
axes[1,1].set_ylabel("")
axes[1,2].set_ylabel("")
fig.supxlabel("Second principal component (Catalan affinity)")
fig.supylabel("Importance (MDI)")
fig.suptitle("Cue-weighting to predict Catalan lexical stress production")
axes[1,3].remove()


# plt.ylim([-1.5,4.5])
plt.savefig('figures/cat_importance_pc2.jpg', format='jpg', dpi = 800)
plt.show();

# %% [markdown]
# ## Get visualization across language profile in English

# %%
df_wd.columns
# Out:
# Index(['partID', 'Language', 'stress_wd', 'vdur_ratio', 'syldur_ratio',
#        's_deltaF_dist_ratio', 'p_deltaF_dist_ratio', 'f0_ratio',
#        'spectilt_ratio', 'creak_ratio'],
#       dtype='object')

# %%
df_wd['partID'].mask(df_wd['partID'] == 'rsj048', 'rsj0489', inplace=True)

# %%
parts.head()
# Out:
#    partID lang_profile
# 0  acj047         mono
# 1  acj297       l1_eng
# 2  acr108       l1_eng
# 3  aei079       l1_eng
# 4  ael236         mono

# %%
df_wd_lang = pd.merge(df_wd, parts, on = "partID", how = "left")
df_wd_lang.head()
# Out:
#    partID Language stress_wd  vdur_ratio  syldur_ratio  s_deltaF_dist_ratio  \
# 0  afs116      cat   Oxytone    0.261180      0.395276             1.815729
# 1  afs116      cat   Oxytone    0.381522      0.400000             2.012473
# 2  afs116      cat   Oxytone    0.624552      0.556075             1.359292
# 3  afs116      cat   Oxytone    0.570409      1.817184             1.597746
# 4  afs116      cat   Oxytone    0.384633      0.507132             1.786464
#
#    p_deltaF_dist_ratio  f0_ratio  spectilt_ratio  creak_ratio lang_profile
# 0             1.083528  0.558519       -0.579015    -0.709090       l1_eng
# 1             2.162328  0.632067        0.874614    34.562557       l1_eng
# 2             2.075453  0.653062        1.108769     3.309907       l1_eng
# 3             1.880766  0.758638        1.062235     2.231388       l1_eng
# 4             1.800815  0.818848        0.879911     5.104952       l1_eng

# %%
eng_lang = df_wd_lang[df_wd_lang['Language']=="eng"].copy()

# %%
y_eng = eng_lang['stress_wd']
X_eng = eng_lang.drop(['stress_wd', 'Language', 'partID', 'lang_profile'], axis = 1)
    
rf_classifier = RandomForestClassifier(random_state = 10)
    
param_grid = { 
    'n_estimators': [500],
    'max_features': ['auto', 'sqrt', 'log2'],
    'max_depth' : np.arange(4,10,1),
    'criterion' :['gini', 'entropy']
}

CV_rfc_eng = GridSearchCV(estimator=rf_classifier, param_grid=param_grid, cv= 5)
CV_rfc_eng.fit(X_eng, y_eng)
    
print("Best RF Estimator: ", CV_rfc_eng.best_params_, "\n")
    
scores_eng = cross_val_score(rf_classifier, X_eng, y_eng.ravel(), cv=5)
print("Accuracy over all data: ", scores_eng.mean())
    
rf_classifier_best_eng = CV_rfc_eng.best_estimator_

cols_eng = X_eng.columns
# Out:
# Best RF Estimator:  {'criterion': 'gini', 'max_depth': 9, 'max_features': 'auto', 'n_estimators': 500}
#
# Accuracy over all data:  0.7939799154334038

# %%
def rf_eng_lang(df, rf_classifier_best, cols):
    lang_profile = []
    stats_list = []
        
    for l in df.lang_profile.unique():
        data = df[df['lang_profile']==l].copy()
        data.drop(['Language', 'partID', 'lang_profile'], axis = 1, inplace = True)
            
        # define predictor label
        y = data['stress_wd']

        # define feature set
        X = data.drop(['stress_wd'], axis = 1)
            
        rf_classifier_best.fit(X, y.ravel())
        stats = cbook.boxplot_stats(np.vstack([tree.feature_importances_ for tree in rf_classifier_best.estimators_]),
                    labels=cols, bootstrap=10000)
        
        stats_list.append(stats)
        lang_profile.append(l)
        
    return(lang_profile, stats_list)

# %%
lang_profile_list, stats_list = rf_eng_lang(eng_lang, rf_classifier_best_eng, cols_eng)

# %%
lang_profile_list
# Out:
# ['l1_eng', 'l3_eng', 'mono']

# %%
fig, ax = plt.subplots(1, 3, figsize = (15,6), sharey = True, sharex = True)
ax[0].bxp(stats_list[0])
ax[1].bxp(stats_list[1])
ax[2].bxp(stats_list[2])
# ax.set_title("Feature importances for L1 English trilinguals")
# ax.set_ylabel("Decrease in impurity")
# ax.set_ylim(-0.05,1)
plt.figure();
